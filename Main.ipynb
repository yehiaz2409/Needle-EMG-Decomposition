# %%
# Importing Necessary Libraries
import matplotlib.pyplot as plt
import math

# %%
T = 20
DiffTh = pow(12.65,5)
Threshold = 11.7 # = 3 * STD(noise)

# %%
def plot_signal(signal, start, end, name):
    plt.plot(signal[start: end])
    plt.xlabel('Time')
    plt.ylabel('Amplitude')
    plt.title('Signal Graph')
    plt.savefig(name, dpi=300, bbox_inches='tight')
    plt.show()
    return plt

# %%
# Read data from Data.txt
with open('Data.txt', 'r') as file:
    data = file.read().splitlines()
    
# Convert data to signal representation
signal = [float(value) for value in data]

plot_signal(signal, 30000, 35000, "signal.png")
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\AUC\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
# Recitifying
rect_signal = [float(0) for value in data]
for i in range(len(signal)):
    rect_signal[i] = abs(signal[i])
    
plot_signal(signal, 30000, 35000, "rect.png")
plot_signal(rect_signal, 30000, 35000, "rect.png")
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\AUC\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# # Step 1

# %%
def step_one(rect_signal, start):
    begin_mu = False
    end_index = 0
    avg = sum(rect_signal[start:start + T])/T
    if avg > Threshold:
        new_avg = avg
        j = 0
        while new_avg > Threshold:
            new_avg = sum(rect_signal[start+j:start+T+j])/T
            j=j+1
        end_index = start + T + j
        
        print("plot inside step1:")
        plt = plot_signal(rect_signal, start, end_index, "temp.png")
        #print(templates_start_index[0])
        plt.show()
        
    return end_index

# %% [markdown]
# # Step 2

# %%
def step_two(rect_signal, start, end):
    is_empty = all(not sublist for sublist in templates_start_index)
    print("emp: ", is_empty)
    if (is_empty):
        templates_start_index.append(start)      
#         plt = plot_signal(signal, start, end, "temp.png")
#         plt.show()
    else:

# %% [markdown]
# # Signal Test Loop (Main)

# %%
end = 0
templates_start_index = []
templates_values = [[]]

for start in range(0, len(rect_signal) - 1):
# for start in range(500, 700):
    if start <= end:
        continue
    
    end = step_one(rect_signal, start)
    print("start: " , start, "   end: ", end)
    if (end == 0):
        continue
        
    # if MUAP found
    found = step_two(rect_signal, start, end)
    start = end + 1
    print("value: ", templates_start_index, "T", T, " end: ", end, " start: ", start)
    break;
# Out:
# start:  1    end:  0
# start:  2    end:  0
# start:  3    end:  0
# start:  4    end:  0
# start:  5    end:  0
# start:  6    end:  0
# start:  7    end:  0
# start:  8    end:  0
# start:  9    end:  0
# start:  10    end:  0
# start:  11    end:  0
# start:  12    end:  0
# start:  13    end:  0
# start:  14    end:  0
# start:  15    end:  0
# start:  16    end:  0
# start:  17    end:  0
# start:  18    end:  0
# start:  19    end:  0
# start:  20    end:  0
# start:  21    end:  0
# start:  22    end:  0
# start:  23    end:  0
# start:  24    end:  0
# start:  25    end:  0
# start:  26    end:  0
# start:  27    end:  0
# start:  28    end:  0
# start:  29    end:  0
# start:  30    end:  0
# start:  31    end:  0
# start:  32    end:  0
# start:  33    end:  0
# start:  34    end:  0
# start:  35    end:  0
# start:  36    end:  0
# start:  37    end:  0
# start:  38    end:  0
# start:  39    end:  0
# start:  40    end:  0
# start:  41    end:  0
# start:  42    end:  0
# ...
